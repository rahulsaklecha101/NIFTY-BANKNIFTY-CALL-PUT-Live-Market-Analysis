# %%
#Final Program
#Imports
import requests
import json
import math
import datetime
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pytz import timezone
import time
import copy
from IPython.display import clear_output
import os

#Initial Parameters
optionChainLink = "https://www.nseindia.com/api/option-chain-indices?symbol=BANKNIFTY"
header_para = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
India_Time = timezone('Asia/Calcutta')  
timeOfData = []
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
master_df = pd.DataFrame()
dataframe_list = [df1, df2, df3, df4, df5, df6]
Support = {}
Resistance = {}
run = 0

# %%
while True:
    
    data = None
    while data is None:
        try:
            with requests.session() as s:
                data = s.get(optionChainLink, headers = header_para).json()
                raw_data = json.dumps(data)
            option = json.loads(raw_data)
            
            #Getting expiry dates from dict
            expiryDates = option['records']['expiryDates'][:1]
        
            #Time of Data Received
            timeOfData = option['records']['timestamp'][-8:-3]
    
            #Date of the Data
            dateOfData = option['records']['timestamp'][:11]
            
        except:
            pass
    
    if run == 0:
        currentNifty = option['records']['underlyingValue']
        new = currentNifty/100
        upper_range = (int(new)*100) + 1800
        lower_range = (int(new)*100) - 1800
        
        OTM_Call_1 = [strike for strike in option['records']['strikePrices'] if currentNifty < strike <= upper_range - 1500]
        OTM_Call_2 = [strike for strike in option['records']['strikePrices'] if currentNifty + 300 < strike <= upper_range - 1200]
        OTM_Call_3 = [strike for strike in option['records']['strikePrices'] if currentNifty + 600 < strike <= upper_range - 900]
        OTM_Call_4 = [strike for strike in option['records']['strikePrices'] if currentNifty + 900 < strike <= upper_range - 600]
        OTM_Call_5 = [strike for strike in option['records']['strikePrices'] if currentNifty + 1200 < strike <= upper_range - 300]
        OTM_Call_6 = [strike for strike in option['records']['strikePrices'] if currentNifty + 1500 < strike <= upper_range]

        OTM_Put_1 = [strike for strike in option['records']['strikePrices'] if  lower_range + 1500 < strike <= currentNifty]
        OTM_Put_2 = [strike for strike in option['records']['strikePrices'] if  lower_range + 1200 < strike <= currentNifty - 300]
        OTM_Put_3 = [strike for strike in option['records']['strikePrices'] if  lower_range + 900 < strike <= currentNifty - 600]
        OTM_Put_4 = [strike for strike in option['records']['strikePrices'] if  lower_range + 600 < strike <= currentNifty - 900]
        OTM_Put_5 = [strike for strike in option['records']['strikePrices'] if  lower_range + 300 < strike <= currentNifty - 1200]
        OTM_Put_6 = [strike for strike in option['records']['strikePrices'] if  lower_range  < strike <= currentNifty - 1500]
        
        OTM_Call = [OTM_Call_1, OTM_Call_2, OTM_Call_3, OTM_Call_4, OTM_Call_5,OTM_Call_6]
        OTM_Put = [OTM_Put_1, OTM_Put_2, OTM_Put_3, OTM_Put_4, OTM_Put_5, OTM_Put_6]
        
        run = run + 1
     
    #Getting expiry dates from dict
    #expiryDates = option['records']['expiryDates'][:1]
        
    #Time of Data Received
    #timeOfData = option['records']['timestamp'][-8:-3]
    
    #Date of the Data
    #dateOfData = option['records']['timestamp'][:11]
        
    PE = 0 
    CE = 0    
        
    for i in range(len(OTM_Call)):
        total_ce = 0
        total_pe = 0
        for block in option['records']['data'][:]:
            if block['strikePrice'] in OTM_Call[i] and block['expiryDate'] in expiryDates:
                try:
                    ce = block['CE']['changeinOpenInterest']
                    total_ce = total_ce + ce
                    CE = CE + ce
                except:
                    ce = 0

            if block['strikePrice'] in OTM_Put[i] and block['expiryDate'] in expiryDates:
                try:
                    pe = block['PE']['changeinOpenInterest']
                    total_pe = total_pe + pe
                    PE = PE + pe
                except:
                    pe = 0
        #Form a Dictionary to append Data to Dataframe
        insert_dict = {'Time' : timeOfData, "OTM_Call" : total_ce, "OTM_Put" : total_pe}
        dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
    
    master_insert = {'Time' : timeOfData, "Total Call" : CE, "Total Put" : PE}
    master_df = master_df.append(master_insert, ignore_index = True)

    #DataFrame is Ready
    
    figs, axs = plt.subplots(figsize = (15,10))
    
    master_df.plot(x = 'Time', title = "Overall Puts and Calls", color = "Red", y = "Total Call", ax = axs)
    master_df.plot(x = "Time", color = "Green", y = "Total Put", ax = axs)
    
    fig, axes = plt.subplots(3, 2,figsize=(18,18))

    count = 0
    for r in range(3):
        for c in range(2):
            name = "Range for OTM Call " + str(OTM_Call[count][0]) + "-" + str(OTM_Call[count][-1]) + " and for OTM Put " + str(OTM_Put[count][0]) + "-" + str(OTM_Put[count][-1])
            dataframe_list[count].plot(x = 'Time', ax = axes[r,c], title = name, color = 'Red', y = "OTM_Call")
            dataframe_list[count].plot(x = 'Time', ax = axes[r,c], color = 'Green', y = "OTM_Put")
            count = count + 1

    plt.show()       
    
    print(f"Current Bank Nifty : {currentNifty}\n")
            
    for block in option['records']['data'][:]:
        if currentNifty <= block['strikePrice'] <= upper_range + 1300 and block['expiryDate'] in expiryDates:
            Resistance[block['strikePrice']] = block['CE']['openInterest']
    Resistance = dict(sorted(Resistance.items(), reverse = True ,key=lambda item: item[1]))
    for i in range(3):
        print("Resistance Level " + str(i + 1) + ": " + str(sorted(list(Resistance.keys())[:5])[:3][i]) + " with " + str(Resistance[sorted(list(Resistance.keys())[:5])[:3][i]]) + " Open Intrests")
    
    print('\n')

    for block in option['records']['data'][:]:
        if lower_range - 1300 <= block['strikePrice'] <= currentNifty and block['expiryDate'] in expiryDates:
            Support[block['strikePrice']] = block['PE']['openInterest']
    Support = dict(sorted(Support.items(), reverse = True ,key=lambda item: item[1]))
    for i in range(3):
        print("Support Level " + str(i + 1) + ": " + str(sorted(list(Support.keys())[:5], reverse = True)[:3][i]) + " with " + str(Support[sorted(list(Support.keys())[:5])[:3][i]]) + " Open Intrests")

    
    if datetime.datetime.now(India_Time).strftime("%H:%M") > '15:30':
        print('Market Closed')
        break
        
    clear_output(wait=True)

    time.sleep(300)
# Out:
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_list[i] = dataframe_list[i].append(insert_dict, ignore_index=True)
# /var/folders/21/ylxbjwr94cv9sfw6qdty5f4h0000gq/T/ipykernel_36872/3335493944.py:84: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(master_insert, ignore_index = True)
# Current Bank Nifty : 50705.55
#
# Resistance Level 1: 51000 with 112771 Open Intrests
# Resistance Level 2: 51500 with 103836 Open Intrests
# Resistance Level 3: 52000 with 144199 Open Intrests
#
#
# Support Level 1: 50500 with 86862 Open Intrests
# Support Level 2: 50000 with 84189 Open Intrests
# Support Level 3: 49500 with 91718 Open Intrests
# Market Closed

# %%
option
# Out:
# {'records': {'expiryDates': ['31-Jul-2024',
#    '07-Aug-2024',
#    '14-Aug-2024',
#    '21-Aug-2024',
#    '28-Aug-2024',
#    '04-Sep-2024',
#    '25-Sep-2024',
#    '24-Dec-2024',
#    '26-Mar-2025',
#    '25-Jun-2025'],
#   'data': [{'strikePrice': 37500,
#     'expiryDate': '25-Sep-2024',
#     'PE': {'strikePrice': 37500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE37500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2700,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 37500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024CE37500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 11784.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 39000,
#     'expiryDate': '25-Sep-2024',
#     'PE': {'strikePrice': 39000,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE39000.00',
#      'openInterest': 7,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 39000,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024CE39000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 10468.75,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 39500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 39500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE39500.00',
#      'openInterest': 125587,
#      'changeinOpenInterest': 66897,
#      'pchangeinOpenInterest': 113.98364286931334,
#      'totalTradedVolume': 703756,
#      'impliedVolatility': 0,
#      'lastPrice': 0.5,
#      'change': -0.15000000000000002,
#      'pChange': -23.076923076923077,
#      'totalBuyQuantity': 1707915,
#      'totalSellQuantity': 1029015,
#      'bidQty': 179400,
#      'bidprice': 0.45,
#      'askQty': 256980,
#      'askPrice': 0.5,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 39500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE39500.00',
#      'openInterest': 95,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 2,
#      'impliedVolatility': 0,
#      'lastPrice': 11400,
#      'change': -775,
#      'pChange': -6.365503080082135,
#      'totalBuyQuantity': 2835,
#      'totalSellQuantity': 3135,
#      'bidQty': 375,
#      'bidprice': 11266.8,
#      'askQty': 300,
#      'askPrice': 11573.45,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 39500,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 39500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE39500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 11430,
#      'change': 1707.6499999999996,
#      'pChange': 17.564169156633938,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 11053.15,
#      'askQty': 300,
#      'askPrice': 11875.7,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 39500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE39500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 40000,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 40000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE40000.00',
#      'openInterest': 32583,
#      'changeinOpenInterest': 29720,
#      'pchangeinOpenInterest': 1038.0719524973804,
#      'totalTradedVolume': 168672,
#      'impliedVolatility': 0,
#      'lastPrice': 0.6,
#      'change': -0.20000000000000007,
#      'pChange': -25.000000000000007,
#      'totalBuyQuantity': 546420,
#      'totalSellQuantity': 125370,
#      'bidQty': 21000,
#      'bidprice': 0.6,
#      'askQty': 43680,
#      'askPrice': 0.65,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 40000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE40000.00',
#      'openInterest': 527,
#      'changeinOpenInterest': -8,
#      'pchangeinOpenInterest': -1.4953271028037383,
#      'totalTradedVolume': 51,
#      'impliedVolatility': 0,
#      'lastPrice': 10900,
#      'change': -400,
#      'pChange': -3.5398230088495577,
#      'totalBuyQuantity': 3105,
#      'totalSellQuantity': 3030,
#      'bidQty': 45,
#      'bidprice': 10900,
#      'askQty': 45,
#      'askPrice': 11034.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 40000,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 40000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE40000.00',
#      'openInterest': 32,
#      'changeinOpenInterest': 29,
#      'pchangeinOpenInterest': 966.6666666666666,
#      'totalTradedVolume': 36,
#      'impliedVolatility': 0,
#      'lastPrice': 11050,
#      'change': -354.7999999999993,
#      'pChange': -3.1109708193041463,
#      'totalBuyQuantity': 3600,
#      'totalSellQuantity': 2415,
#      'bidQty': 615,
#      'bidprice': 10675.95,
#      'askQty': 300,
#      'askPrice': 11150,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 40000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE40000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 40500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 40500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE40500.00',
#      'openInterest': 4237,
#      'changeinOpenInterest': 4108,
#      'pchangeinOpenInterest': 3184.4961240310076,
#      'totalTradedVolume': 22536,
#      'impliedVolatility': 0,
#      'lastPrice': 0.85,
#      'change': -0.35,
#      'pChange': -29.166666666666668,
#      'totalBuyQuantity': 156615,
#      'totalSellQuantity': 21030,
#      'bidQty': 15,
#      'bidprice': 0.65,
#      'askQty': 600,
#      'askPrice': 1,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 40500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE40500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2085,
#      'bidQty': 300,
#      'bidprice': 9744.9,
#      'askQty': 300,
#      'askPrice': 10921.05,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 40500,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 40500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE40500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 40500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE40500.00',
#      'openInterest': 3,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 9937.85,
#      'askQty': 300,
#      'askPrice': 10868.3,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 40500,
#     'expiryDate': '25-Sep-2024',
#     'PE': {'strikePrice': 40500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE40500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 4.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 40500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024CE40500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 9150.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 41000,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 41000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE41000.00',
#      'openInterest': 6151,
#      'changeinOpenInterest': 5799,
#      'pchangeinOpenInterest': 1647.4431818181818,
#      'totalTradedVolume': 34831,
#      'impliedVolatility': 0,
#      'lastPrice': 0.75,
#      'change': -0.8999999999999999,
#      'pChange': -54.54545454545454,
#      'totalBuyQuantity': 180315,
#      'totalSellQuantity': 10920,
#      'bidQty': 10245,
#      'bidprice': 0.75,
#      'askQty': 900,
#      'askPrice': 1.45,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 41000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE41000.00',
#      'openInterest': 38,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3285,
#      'totalSellQuantity': 3000,
#      'bidQty': 300,
#      'bidprice': 9530,
#      'askQty': 15,
#      'askPrice': 9984.3,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 41000,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 41000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE41000.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 10100,
#      'change': -322.5,
#      'pChange': -3.0942672103621973,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 9721.9,
#      'askQty': 300,
#      'askPrice': 10365.55,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 41000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE41000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4200,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.8,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 41500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 41500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE41500.00',
#      'openInterest': 5682,
#      'changeinOpenInterest': 4972,
#      'pchangeinOpenInterest': 700.2816901408451,
#      'totalTradedVolume': 34918,
#      'impliedVolatility': 0,
#      'lastPrice': 0.8,
#      'change': -1.2499999999999998,
#      'pChange': -60.97560975609756,
#      'totalBuyQuantity': 116625,
#      'totalSellQuantity': 19245,
#      'bidQty': 765,
#      'bidprice': 0.8,
#      'askQty': 150,
#      'askPrice': 0.85,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 41500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE41500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2535,
#      'totalSellQuantity': 2235,
#      'bidQty': 300,
#      'bidprice': 9218.75,
#      'askQty': 150,
#      'askPrice': 9547,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 41500,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 41500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE41500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4620,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 3.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 41500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE41500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 8996.35,
#      'askQty': 300,
#      'askPrice': 9863.2,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 42000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE42000.00',
#      'openInterest': 319,
#      'changeinOpenInterest': -118,
#      'pchangeinOpenInterest': -27.002288329519452,
#      'totalTradedVolume': 209,
#      'impliedVolatility': 0,
#      'lastPrice': 8853.75,
#      'change': -517.1499999999996,
#      'pChange': -5.518680169460774,
#      'totalBuyQuantity': 2985,
#      'totalSellQuantity': 2100,
#      'bidQty': 375,
#      'bidprice': 8764.35,
#      'askQty': 15,
#      'askPrice': 9052.75,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 42000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE42000.00',
#      'openInterest': 8664,
#      'changeinOpenInterest': 5327,
#      'pchangeinOpenInterest': 159.63440215762662,
#      'totalTradedVolume': 38170,
#      'impliedVolatility': 0,
#      'lastPrice': 1,
#      'change': -1.2999999999999998,
#      'pChange': -56.52173913043478,
#      'totalBuyQuantity': 131790,
#      'totalSellQuantity': 23835,
#      'bidQty': 1980,
#      'bidprice': 1,
#      'askQty': 510,
#      'askPrice': 1.1,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42000,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 42000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE42000.00',
#      'openInterest': 147,
#      'changeinOpenInterest': 114,
#      'pchangeinOpenInterest': 345.45454545454544,
#      'totalTradedVolume': 117,
#      'impliedVolatility': 0,
#      'lastPrice': 9146.4,
#      'change': -340.39999999999964,
#      'pChange': -3.5881435257410264,
#      'totalBuyQuantity': 2970,
#      'totalSellQuantity': 2460,
#      'bidQty': 885,
#      'bidprice': 8487.6,
#      'askQty': 390,
#      'askPrice': 9354.8,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 42000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE42000.00',
#      'openInterest': 48,
#      'changeinOpenInterest': 28,
#      'pchangeinOpenInterest': 140,
#      'totalTradedVolume': 75,
#      'impliedVolatility': 0,
#      'lastPrice': 8.55,
#      'change': 1.0000000000000009,
#      'pChange': 13.245033112582794,
#      'totalBuyQuantity': 5070,
#      'totalSellQuantity': 315,
#      'bidQty': 540,
#      'bidprice': 7.7,
#      'askQty': 15,
#      'askPrice': 13,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42000,
#     'expiryDate': '25-Sep-2024',
#     'CE': {'strikePrice': 42000,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024CE42000.00',
#      'openInterest': 10,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 330,
#      'totalSellQuantity': 0,
#      'bidQty': 330,
#      'bidprice': 7209.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 42000,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE42000.00',
#      'openInterest': 250,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 34,
#      'impliedVolatility': 0,
#      'lastPrice': 26,
#      'change': 0.6499999999999986,
#      'pChange': 2.5641025641025585,
#      'totalBuyQuantity': 2880,
#      'totalSellQuantity': 285,
#      'bidQty': 90,
#      'bidprice': 23.15,
#      'askQty': 30,
#      'askPrice': 28.95,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42000,
#     'expiryDate': '24-Dec-2024',
#     'PE': {'strikePrice': 42000,
#      'expiryDate': '24-Dec-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-12-2024PE42000.00',
#      'openInterest': 408,
#      'changeinOpenInterest': 32,
#      'pchangeinOpenInterest': 8.51063829787234,
#      'totalTradedVolume': 38,
#      'impliedVolatility': 0,
#      'lastPrice': 100.05,
#      'change': -9.950000000000003,
#      'pChange': -9.045454545454549,
#      'totalBuyQuantity': 2265,
#      'totalSellQuantity': 270,
#      'bidQty': 900,
#      'bidprice': 76.25,
#      'askQty': 120,
#      'askPrice': 110,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 42500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE42500.00',
#      'openInterest': 14603,
#      'changeinOpenInterest': 12055,
#      'pchangeinOpenInterest': 473.11616954474096,
#      'totalTradedVolume': 50304,
#      'impliedVolatility': 0,
#      'lastPrice': 1.2,
#      'change': -0.75,
#      'pChange': -38.46153846153847,
#      'totalBuyQuantity': 105570,
#      'totalSellQuantity': 17745,
#      'bidQty': 60,
#      'bidprice': 1.05,
#      'askQty': 900,
#      'askPrice': 1.7,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 42500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE42500.00',
#      'openInterest': 8,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2400,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 7982.75,
#      'askQty': 300,
#      'askPrice': 8779.55,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 42500,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 42500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE42500.00',
#      'openInterest': 11,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 8075.2,
#      'askQty': 300,
#      'askPrice': 8859.1,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 42500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE42500.00',
#      'openInterest': 15,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 25.37,
#      'lastPrice': 8.55,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4020,
#      'totalSellQuantity': 0,
#      'bidQty': 105,
#      'bidprice': 5.45,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43000,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 43000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE43000.00',
#      'openInterest': 9499,
#      'changeinOpenInterest': 4182,
#      'pchangeinOpenInterest': 78.65337596388942,
#      'totalTradedVolume': 36239,
#      'impliedVolatility': 0,
#      'lastPrice': 1.2,
#      'change': -1.5999999999999999,
#      'pChange': -57.14285714285714,
#      'totalBuyQuantity': 158220,
#      'totalSellQuantity': 18690,
#      'bidQty': 405,
#      'bidprice': 1.2,
#      'askQty': 600,
#      'askPrice': 2.5,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 43000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE43000.00',
#      'openInterest': 1835,
#      'changeinOpenInterest': -9,
#      'pchangeinOpenInterest': -0.4880694143167028,
#      'totalTradedVolume': 13,
#      'impliedVolatility': 0,
#      'lastPrice': 7800,
#      'change': -550,
#      'pChange': -6.58682634730539,
#      'totalBuyQuantity': 3045,
#      'totalSellQuantity': 3000,
#      'bidQty': 375,
#      'bidprice': 7759.45,
#      'askQty': 15,
#      'askPrice': 7943.05,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43000,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 43000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE43000.00',
#      'openInterest': 262,
#      'changeinOpenInterest': 2,
#      'pchangeinOpenInterest': 0.7692307692307693,
#      'totalTradedVolume': 14,
#      'impliedVolatility': 0,
#      'lastPrice': 8080,
#      'change': -460.7000000000007,
#      'pChange': -5.3941714379383505,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2115,
#      'bidQty': 615,
#      'bidprice': 7702,
#      'askQty': 300,
#      'askPrice': 8342.15,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 43000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE43000.00',
#      'openInterest': 41,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 7,
#      'impliedVolatility': 0,
#      'lastPrice': 20,
#      'change': -2.25,
#      'pChange': -10.112359550561797,
#      'totalBuyQuantity': 2940,
#      'totalSellQuantity': 0,
#      'bidQty': 105,
#      'bidprice': 7.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 43500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE43500.00',
#      'openInterest': 1211,
#      'changeinOpenInterest': 545,
#      'pchangeinOpenInterest': 81.83183183183183,
#      'totalTradedVolume': 16580,
#      'impliedVolatility': 0,
#      'lastPrice': 1.4,
#      'change': -1.85,
#      'pChange': -56.92307692307692,
#      'totalBuyQuantity': 124335,
#      'totalSellQuantity': 11685,
#      'bidQty': 540,
#      'bidprice': 1.4,
#      'askQty': 900,
#      'askPrice': 1.6,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 43500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE43500.00',
#      'openInterest': 41,
#      'changeinOpenInterest': -8,
#      'pchangeinOpenInterest': -16.3265306122449,
#      'totalTradedVolume': 22,
#      'impliedVolatility': 0,
#      'lastPrice': 7180,
#      'change': -1620,
#      'pChange': -18.409090909090907,
#      'totalBuyQuantity': 3285,
#      'totalSellQuantity': 2640,
#      'bidQty': 300,
#      'bidprice': 7242.3,
#      'askQty': 300,
#      'askPrice': 7540,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43500,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 43500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE43500.00',
#      'openInterest': 13,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2685,
#      'bidQty': 615,
#      'bidprice': 7111.25,
#      'askQty': 615,
#      'askPrice': 7910.35,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 43500,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE43500.00',
#      'openInterest': 78,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 23.95,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 5610,
#      'totalSellQuantity': 300,
#      'bidQty': 105,
#      'bidprice': 8.8,
#      'askQty': 300,
#      'askPrice': 26.85,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43500,
#     'expiryDate': '25-Sep-2024',
#     'CE': {'strikePrice': 43500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024CE43500.00',
#      'openInterest': 16,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 7693.3,
#      'change': -495.14999999999964,
#      'pChange': -6.0469319590398625,
#      'totalBuyQuantity': 330,
#      'totalSellQuantity': 0,
#      'bidQty': 330,
#      'bidprice': 6201.75,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 43500,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE43500.00',
#      'openInterest': 86,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 23.84,
#      'lastPrice': 71,
#      'change': 37,
#      'pChange': 108.8235294117647,
#      'totalBuyQuantity': 2130,
#      'totalSellQuantity': 15,
#      'bidQty': 15,
#      'bidprice': 40,
#      'askQty': 15,
#      'askPrice': 50,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43500,
#     'expiryDate': '24-Dec-2024',
#     'PE': {'strikePrice': 43500,
#      'expiryDate': '24-Dec-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-12-2024PE43500.00',
#      'openInterest': 386,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4680,
#      'totalSellQuantity': 315,
#      'bidQty': 15,
#      'bidprice': 75.1,
#      'askQty': 150,
#      'askPrice': 175,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43900,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 43900,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE43900.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 6776.15,
#      'askQty': 300,
#      'askPrice': 7509.6,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 43900,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE43900.00',
#      'openInterest': 307,
#      'changeinOpenInterest': 97,
#      'pchangeinOpenInterest': 46.19047619047619,
#      'totalTradedVolume': 3388,
#      'impliedVolatility': 0,
#      'lastPrice': 1.4,
#      'change': -2.2,
#      'pChange': -61.111111111111114,
#      'totalBuyQuantity': 108885,
#      'totalSellQuantity': 5370,
#      'bidQty': 900,
#      'bidprice': 1.1,
#      'askQty': 30,
#      'askPrice': 1.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 43900,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 43900,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE43900.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2685,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 7.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 43900,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE43900.00',
#      'openInterest': 9,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 6724.4,
#      'askQty': 300,
#      'askPrice': 7446.15,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE44000.00',
#      'openInterest': 39352,
#      'changeinOpenInterest': -3580,
#      'pchangeinOpenInterest': -8.338768284729339,
#      'totalTradedVolume': 114591,
#      'impliedVolatility': 0,
#      'lastPrice': 1.65,
#      'change': -2.0500000000000003,
#      'pChange': -55.4054054054054,
#      'totalBuyQuantity': 192945,
#      'totalSellQuantity': 39555,
#      'bidQty': 795,
#      'bidprice': 1.65,
#      'askQty': 90,
#      'askPrice': 1.75,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE44000.00',
#      'openInterest': 449,
#      'changeinOpenInterest': -31,
#      'pchangeinOpenInterest': -6.458333333333333,
#      'totalTradedVolume': 86,
#      'impliedVolatility': 0,
#      'lastPrice': 6911,
#      'change': -466.4499999999998,
#      'pChange': -6.322645358491075,
#      'totalBuyQuantity': 3120,
#      'totalSellQuantity': 2175,
#      'bidQty': 15,
#      'bidprice': 6795.7,
#      'askQty': 45,
#      'askPrice': 6942.55,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '07-Aug-2024',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '07-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY07-08-2024PE44000.00',
#      'openInterest': 260,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 285,
#      'impliedVolatility': 0,
#      'lastPrice': 5.3,
#      'change': 3,
#      'pChange': 130.43478260869566,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 450,
#      'bidQty': 180,
#      'bidprice': 3.55,
#      'askQty': 210,
#      'askPrice': 5.25,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '07-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY07-08-2024CE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1185,
#      'totalSellQuantity': 1185,
#      'bidQty': 300,
#      'bidprice': 6437.5,
#      'askQty': 300,
#      'askPrice': 7481.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '14-Aug-2024',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '14-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY14-08-2024PE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1785,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '14-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY14-08-2024CE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 885,
#      'totalSellQuantity': 885,
#      'bidQty': 885,
#      'bidprice': 6343.75,
#      'askQty': 885,
#      'askPrice': 7864.75,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '21-Aug-2024',
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '21-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY21-08-2024CE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 885,
#      'totalSellQuantity': 885,
#      'bidQty': 885,
#      'bidprice': 6404.6,
#      'askQty': 885,
#      'askPrice': 7840.1,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '21-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY21-08-2024PE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1980,
#      'totalSellQuantity': 0,
#      'bidQty': 195,
#      'bidprice': 4.65,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE44000.00',
#      'openInterest': 70,
#      'changeinOpenInterest': 60,
#      'pchangeinOpenInterest': 600,
#      'totalTradedVolume': 68,
#      'impliedVolatility': 0,
#      'lastPrice': 7100,
#      'change': -333.60000000000036,
#      'pChange': -4.48773138183384,
#      'totalBuyQuantity': 3165,
#      'totalSellQuantity': 3585,
#      'bidQty': 615,
#      'bidprice': 6722,
#      'askQty': 615,
#      'askPrice': 7394.6,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE44000.00',
#      'openInterest': 929,
#      'changeinOpenInterest': 51,
#      'pchangeinOpenInterest': 5.808656036446469,
#      'totalTradedVolume': 280,
#      'impliedVolatility': 0,
#      'lastPrice': 19,
#      'change': -0.5500000000000007,
#      'pChange': -2.8132992327365764,
#      'totalBuyQuantity': 15615,
#      'totalSellQuantity': 2235,
#      'bidQty': 75,
#      'bidprice': 16.85,
#      'askQty': 75,
#      'askPrice': 20.25,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '04-Sep-2024',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '04-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY04-09-2024PE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2700,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44000,
#     'expiryDate': '25-Sep-2024',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '25-Sep-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-09-2024PE44000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 50,
#      'change': -26.349999999999994,
#      'pChange': -34.51211525867714,
#      'totalBuyQuantity': 960,
#      'totalSellQuantity': 0,
#      'bidQty': 60,
#      'bidprice': 13.45,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44100,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 44100,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE44100.00',
#      'openInterest': 487,
#      'changeinOpenInterest': 134,
#      'pchangeinOpenInterest': 37.960339943342774,
#      'totalTradedVolume': 12064,
#      'impliedVolatility': 0,
#      'lastPrice': 1.3,
#      'change': -1.4999999999999998,
#      'pChange': -53.57142857142857,
#      'totalBuyQuantity': 70995,
#      'totalSellQuantity': 6855,
#      'bidQty': 3510,
#      'bidprice': 1.3,
#      'askQty': 300,
#      'askPrice': 1.35,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44100,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE44100.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 6581,
#      'askQty': 300,
#      'askPrice': 7308.75,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44100,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 44100,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE44100.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 12,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44100,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE44100.00',
#      'openInterest': 8,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 6526.25,
#      'askQty': 300,
#      'askPrice': 7289.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44200,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 44200,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE44200.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2985,
#      'totalSellQuantity': 3285,
#      'bidQty': 375,
#      'bidprice': 6573.05,
#      'askQty': 300,
#      'askPrice': 6867.7,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 44200,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE44200.00',
#      'openInterest': 473,
#      'changeinOpenInterest': 118,
#      'pchangeinOpenInterest': 33.23943661971831,
#      'totalTradedVolume': 3765,
#      'impliedVolatility': 0,
#      'lastPrice': 1.4,
#      'change': -1.7000000000000002,
#      'pChange': -54.83870967741936,
#      'totalBuyQuantity': 77280,
#      'totalSellQuantity': 4620,
#      'bidQty': 60,
#      'bidprice': 1.15,
#      'askQty': 75,
#      'askPrice': 1.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44200,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 44200,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE44200.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 12,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44200,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE44200.00',
#      'openInterest': 9,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 6423.55,
#      'askQty': 300,
#      'askPrice': 7144.1,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44300,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 44300,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE44300.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2985,
#      'totalSellQuantity': 3285,
#      'bidQty': 150,
#      'bidprice': 6469.15,
#      'askQty': 300,
#      'askPrice': 6745.1,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 44300,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE44300.00',
#      'openInterest': 159,
#      'changeinOpenInterest': 62,
#      'pchangeinOpenInterest': 63.91752577319588,
#      'totalTradedVolume': 4003,
#      'impliedVolatility': 37.4,
#      'lastPrice': 1.15,
#      'change': -1.5500000000000003,
#      'pChange': -57.40740740740742,
#      'totalBuyQuantity': 66540,
#      'totalSellQuantity': 4620,
#      'bidQty': 855,
#      'bidprice': 1.15,
#      'askQty': 30,
#      'askPrice': 1.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44300,
#     'expiryDate': '28-Aug-2024',
#     'PE': {'strikePrice': 44300,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE44300.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1890,
#      'totalSellQuantity': 0,
#      'bidQty': 90,
#      'bidprice': 12.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44300,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE44300.00',
#      'openInterest': 8,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 6333.7,
#      'askQty': 300,
#      'askPrice': 7091.4,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44400,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 44400,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE44400.00',
#      'openInterest': 504,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 0.1988071570576541,
#      'totalTradedVolume': 3253,
#      'impliedVolatility': 0,
#      'lastPrice': 1.6,
#      'change': -1.6,
#      'pChange': -50,
#      'totalBuyQuantity': 67635,
#      'totalSellQuantity': 10980,
#      'bidQty': 75,
#      'bidprice': 1.25,
#      'askQty': 105,
#      'askPrice': 1.6,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 44400,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE44400.00',
#      'openInterest': 9,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 6314.4,
#      'askQty': 300,
#      'askPrice': 6693.75,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 44400,
#     'expiryDate': '28-Aug-2024',
#     'CE': {'strikePrice': 44400,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024CE44400.00',
#      'openInterest': 8,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3585,
#      'totalSellQuantity': 2070,
#      'bidQty': 615,
#      'bidprice': 6229.6,
#      'askQty': 300,
#      'askPrice': 6991.25,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 44400,
#      'expiryDate': '28-Aug-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-08-2024PE44400.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
# ...
#      'openInterest': 1364,
#      'changeinOpenInterest': -169,
#      'pchangeinOpenInterest': -11.024135681669929,
#      'totalTradedVolume': 6669,
#      'impliedVolatility': 0,
#      'lastPrice': 3.2,
#      'change': -1.9500000000000002,
#      'pChange': -37.86407766990291,
#      'totalBuyQuantity': 124815,
#      'totalSellQuantity': 5490,
#      'bidQty': 330,
#      'bidprice': 3.2,
#      'askQty': 45,
#      'askPrice': 3.45,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 55800,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE55800.00',
#      'openInterest': 8,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2415,
#      'bidQty': 300,
#      'bidprice': 4710,
#      'askQty': 300,
#      'askPrice': 4999.15,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 55900,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 55900,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE55900.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 4808.5,
#      'askQty': 300,
#      'askPrice': 5141.55,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 55900,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE55900.00',
#      'openInterest': 702,
#      'changeinOpenInterest': 206,
#      'pchangeinOpenInterest': 41.53225806451613,
#      'totalTradedVolume': 4107,
#      'impliedVolatility': 0,
#      'lastPrice': 3.2,
#      'change': -1.8999999999999995,
#      'pChange': -37.2549019607843,
#      'totalBuyQuantity': 133485,
#      'totalSellQuantity': 5325,
#      'bidQty': 900,
#      'bidprice': 2.3,
#      'askQty': 810,
#      'askPrice': 7.7,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 56000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 56000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE56000.00',
#      'openInterest': 45585,
#      'changeinOpenInterest': 5676,
#      'pchangeinOpenInterest': 14.222355859580546,
#      'totalTradedVolume': 188616,
#      'impliedVolatility': 0,
#      'lastPrice': 2.8,
#      'change': -2.1500000000000004,
#      'pChange': -43.43434343434344,
#      'totalBuyQuantity': 186660,
#      'totalSellQuantity': 12435,
#      'bidQty': 45,
#      'bidprice': 2.95,
#      'askQty': 675,
#      'askPrice': 3.25,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 56000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE56000.00',
#      'openInterest': 2256,
#      'changeinOpenInterest': -22,
#      'pchangeinOpenInterest': -0.9657594381035997,
#      'totalTradedVolume': 129,
#      'impliedVolatility': 0,
#      'lastPrice': 5073.2,
#      'change': 445.25,
#      'pChange': 9.620890459058547,
#      'totalBuyQuantity': 3300,
#      'totalSellQuantity': 3300,
#      'bidQty': 45,
#      'bidprice': 5064.05,
#      'askQty': 45,
#      'askPrice': 5097.65,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 56100,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 56100,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE56100.00',
#      'openInterest': 2,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2535,
#      'totalSellQuantity': 2265,
#      'bidQty': 300,
#      'bidprice': 5023.8,
#      'askQty': 30,
#      'askPrice': 5273.6,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 56100,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE56100.00',
#      'openInterest': 933,
#      'changeinOpenInterest': -31,
#      'pchangeinOpenInterest': -3.215767634854772,
#      'totalTradedVolume': 8906,
#      'impliedVolatility': 0,
#      'lastPrice': 3,
#      'change': -2.05,
#      'pChange': -40.59405940594059,
#      'totalBuyQuantity': 118200,
#      'totalSellQuantity': 5460,
#      'bidQty': 45,
#      'bidprice': 3.15,
#      'askQty': 45,
#      'askPrice': 3.35,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 56500,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 56500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE56500.00',
#      'openInterest': 29855,
#      'changeinOpenInterest': 19411,
#      'pchangeinOpenInterest': 185.85790884718497,
#      'totalTradedVolume': 145455,
#      'impliedVolatility': 31.06,
#      'lastPrice': 3.5,
#      'change': -1.25,
#      'pChange': -26.31578947368421,
#      'totalBuyQuantity': 150135,
#      'totalSellQuantity': 8910,
#      'bidQty': 45,
#      'bidprice': 3.2,
#      'askQty': 150,
#      'askPrice': 3.5,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 56500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE56500.00',
#      'openInterest': 40,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2910,
#      'totalSellQuantity': 2910,
#      'bidQty': 300,
#      'bidprice': 5407.8,
#      'askQty': 300,
#      'askPrice': 5695.1,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 57000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 57000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE57000.00',
#      'openInterest': 37079,
#      'changeinOpenInterest': 1709,
#      'pchangeinOpenInterest': 4.831778343228725,
#      'totalTradedVolume': 88614,
#      'impliedVolatility': 0,
#      'lastPrice': 2.9,
#      'change': -2.0000000000000004,
#      'pChange': -40.81632653061225,
#      'totalBuyQuantity': 163290,
#      'totalSellQuantity': 9585,
#      'bidQty': 345,
#      'bidprice': 2.9,
#      'askQty': 600,
#      'askPrice': 4.2,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 57000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE57000.00',
#      'openInterest': 2427,
#      'changeinOpenInterest': -38,
#      'pchangeinOpenInterest': -1.54158215010142,
#      'totalTradedVolume': 44,
#      'impliedVolatility': 0,
#      'lastPrice': 6032.25,
#      'change': 441.5,
#      'pChange': 7.896972678084335,
#      'totalBuyQuantity': 3225,
#      'totalSellQuantity': 3195,
#      'bidQty': 30,
#      'bidprice': 6058.6,
#      'askQty': 30,
#      'askPrice': 6177.55,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 57500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 57500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE57500.00',
#      'openInterest': 22,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3285,
#      'totalSellQuantity': 2985,
#      'bidQty': 300,
#      'bidprice': 6399.05,
#      'askQty': 150,
#      'askPrice': 6688.9,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 57500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE57500.00',
#      'openInterest': 63100,
#      'changeinOpenInterest': 47086,
#      'pchangeinOpenInterest': 294.0302235543899,
#      'totalTradedVolume': 222812,
#      'impliedVolatility': 0,
#      'lastPrice': 3.25,
#      'change': -1.6500000000000004,
#      'pChange': -33.673469387755105,
#      'totalBuyQuantity': 196665,
#      'totalSellQuantity': 14940,
#      'bidQty': 60,
#      'bidprice': 3.25,
#      'askQty': 465,
#      'askPrice': 3.4,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 58000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 58000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE58000.00',
#      'openInterest': 31222,
#      'changeinOpenInterest': 14695,
#      'pchangeinOpenInterest': 88.91510861015308,
#      'totalTradedVolume': 90895,
#      'impliedVolatility': 0,
#      'lastPrice': 2.95,
#      'change': -1.5,
#      'pChange': -33.70786516853933,
#      'totalBuyQuantity': 180945,
#      'totalSellQuantity': 26490,
#      'bidQty': 15,
#      'bidprice': 2.9,
#      'askQty': 1515,
#      'askPrice': 2.95,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 58000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE58000.00',
#      'openInterest': 477,
#      'changeinOpenInterest': -5,
#      'pchangeinOpenInterest': -1.037344398340249,
#      'totalTradedVolume': 15,
#      'impliedVolatility': 0,
#      'lastPrice': 7012.15,
#      'change': 496,
#      'pChange': 7.611856694520538,
#      'totalBuyQuantity': 3195,
#      'totalSellQuantity': 3165,
#      'bidQty': 45,
#      'bidprice': 7054.85,
#      'askQty': 180,
#      'askPrice': 7094.8,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 58500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 58500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE58500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2910,
#      'totalSellQuantity': 2640,
#      'bidQty': 300,
#      'bidprice': 7377.9,
#      'askQty': 30,
#      'askPrice': 7682.2,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 58500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE58500.00',
#      'openInterest': 13312,
#      'changeinOpenInterest': 8587,
#      'pchangeinOpenInterest': 181.73544973544975,
#      'totalTradedVolume': 66417,
#      'impliedVolatility': 0,
#      'lastPrice': 2.65,
#      'change': -1.65,
#      'pChange': -38.372093023255815,
#      'totalBuyQuantity': 156810,
#      'totalSellQuantity': 22800,
#      'bidQty': 885,
#      'bidprice': 2.65,
#      'askQty': 600,
#      'askPrice': 3.35,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 59000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 59000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE59000.00',
#      'openInterest': 33801,
#      'changeinOpenInterest': 14887,
#      'pchangeinOpenInterest': 78.7088928835783,
#      'totalTradedVolume': 117527,
#      'impliedVolatility': 40.94,
#      'lastPrice': 2.35,
#      'change': -1.85,
#      'pChange': -44.047619047619044,
#      'totalBuyQuantity': 242325,
#      'totalSellQuantity': 27315,
#      'bidQty': 6285,
#      'bidprice': 2.35,
#      'askQty': 3600,
#      'askPrice': 2.5,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 59000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE59000.00',
#      'openInterest': 345,
#      'changeinOpenInterest': -1,
#      'pchangeinOpenInterest': -0.28901734104046245,
#      'totalTradedVolume': 5,
#      'impliedVolatility': 0,
#      'lastPrice': 8100,
#      'change': 523.8000000000002,
#      'pChange': 6.913756236635783,
#      'totalBuyQuantity': 3015,
#      'totalSellQuantity': 3015,
#      'bidQty': 30,
#      'bidprice': 7961.8,
#      'askQty': 30,
#      'askPrice': 8121.5,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 59500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 59500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE59500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2385,
#      'totalSellQuantity': 2385,
#      'bidQty': 300,
#      'bidprice': 8392.2,
#      'askQty': 300,
#      'askPrice': 8860.7,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 59500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE59500.00',
#      'openInterest': 14472,
#      'changeinOpenInterest': 9342,
#      'pchangeinOpenInterest': 182.10526315789474,
#      'totalTradedVolume': 68523,
#      'impliedVolatility': 0,
#      'lastPrice': 2.25,
#      'change': -1.8499999999999996,
#      'pChange': -45.12195121951219,
#      'totalBuyQuantity': 157155,
#      'totalSellQuantity': 10650,
#      'bidQty': 8760,
#      'bidprice': 2.25,
#      'askQty': 1230,
#      'askPrice': 2.6,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 60000,
#     'expiryDate': '31-Jul-2024',
#     'CE': {'strikePrice': 60000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE60000.00',
#      'openInterest': 88547,
#      'changeinOpenInterest': 47186,
#      'pchangeinOpenInterest': 114.08331520030947,
#      'totalTradedVolume': 226145,
#      'impliedVolatility': 45.41,
#      'lastPrice': 2.4,
#      'change': -1.5,
#      'pChange': -38.46153846153847,
#      'totalBuyQuantity': 206910,
#      'totalSellQuantity': 54780,
#      'bidQty': 465,
#      'bidprice': 2.35,
#      'askQty': 615,
#      'askPrice': 2.4,
#      'underlyingValue': 50874.65},
#     'PE': {'strikePrice': 60000,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE60000.00',
#      'openInterest': 74,
#      'changeinOpenInterest': 6,
#      'pchangeinOpenInterest': 8.823529411764707,
#      'totalTradedVolume': 11,
#      'impliedVolatility': 0,
#      'lastPrice': 9000,
#      'change': 459.89999999999964,
#      'pChange': 5.385182843292228,
#      'totalBuyQuantity': 3165,
#      'totalSellQuantity': 3165,
#      'bidQty': 30,
#      'bidprice': 8934.5,
#      'askQty': 30,
#      'askPrice': 9107.2,
#      'underlyingValue': 50874.65}},
#    {'strikePrice': 60500,
#     'expiryDate': '31-Jul-2024',
#     'PE': {'strikePrice': 60500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024PE60500.00',
#      'openInterest': 6,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2535,
#      'totalSellQuantity': 2265,
#      'bidQty': 300,
#      'bidprice': 9361.3,
#      'askQty': 30,
#      'askPrice': 9680.65,
#      'underlyingValue': 50874.65},
#     'CE': {'strikePrice': 60500,
#      'expiryDate': '31-Jul-2024',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY31-07-2024CE60500.00',
#      'openInterest': 109405,
#      'changeinOpenInterest': 24862,
#      'pchangeinOpenInterest': 29.407520433388925,
#      'totalTradedVolume': 332917,
#      'impliedVolatility': 0,
#      'lastPrice': 2.15,
#      'change': -1.65,
#      'pChange': -43.42105263157895,
#      'totalBuyQuantity': 231030,
#      'totalSellQuantity': 138435,
#      'bidQty': 720,
#      'bidprice': 2.15,
#      'askQty': 4680,
#      'askPrice': 2.2,
#      'underlyingValue': 50874.65}}],
#   'CE': {'totOI': 2417971, 'totVol': 25254544},
#   'PE': {'totOI': 1841989, 'totVol': 26266823}}}
